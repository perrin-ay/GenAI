# %% [markdown]
# **Update gcloud components**

# %%
gcloud components update

# %% [markdown]
# **INIT gcloud sdk shell with your project and region**

# %%
>gcloud init
Welcome! This command will take you through the configuration of gcloud.

# %% [markdown]
# **Cloud build**
# - create an Artifact Registry repo of type docker in gcp
# - run the below gcloud command
# - your repo directory includes all code along with Dockerfile
# - if successful the new docker image should show on your Artifact Registry repo

# %%
#gcloud builds submit <Your repo directory> --tag <region>-docker.pkg.dev/<project_name>/<gcloud artifact registry repo name>/<name of instance>
gcloud builds submit "D:\Repos\gcloud\alteoncliguiderag" --tag us-central1-docker.pkg.dev/extreme-zephyr-159021/rag/cliguide01

# %% [markdown]
# **Cloud Run**
#
# Create service - > select docket image from artifact registry
#
# ![image.png](data:image/png;base64,...)
